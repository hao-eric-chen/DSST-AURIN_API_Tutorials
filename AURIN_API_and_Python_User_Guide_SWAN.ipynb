# %% [markdown]
# # Setup WFS Service with the parameters supplied by AURIN Data Provider

# %% [markdown]
# In this tutorial, our goal is to use Python to connect to AURIN API and download dataset.
#
# First, we need to install **OWSLib** using the command `!pip install` in our [SWAN](https://swan.cloudstor.aarnet.edu.au/) environment. **OWSLib** is a Python package that we use to connect to AURIN data provider. For more information about OWSLib, please check [OWSLib documentation](https://geopython.github.io/OWSLib/usage.html) or [GitHub Pages](https://github.com/geopython/OWSLib).

# %%
# !pip install owslib
# Out:
# Requirement already satisfied: owslib in ./.local/lib/python3.9/site-packages (0.25.0)
# Requirement already satisfied: pyproj>=2 in /cvmfs/sft.cern.ch/lcg/views/LCG_101swan/x86_64-centos7-gcc8-opt/lib/python3.9/site-packages (from owslib) (3.0.1)
# Requirement already satisfied: python-dateutil>=1.5 in /extras/cloudstor/python/pre (from owslib) (2.8.2)
# Requirement already satisfied: pyyaml in /extras/cloudstor/python/pre (from owslib) (6.0)
# Requirement already satisfied: pytz in /extras/cloudstor/python/pre (from owslib) (2022.1)
# Requirement already satisfied: requests>=1.0 in /cvmfs/sft.cern.ch/lcg/views/LCG_101swan/x86_64-centos7-gcc8-opt/lib/python3.9/site-packages (from owslib) (2.26.0)
# Requirement already satisfied: certifi in /cvmfs/sft.cern.ch/lcg/views/LCG_101swan/x86_64-centos7-gcc8-opt/lib/python3.9/site-packages (from pyproj>=2->owslib) (2021.5.30)
# Requirement already satisfied: six>=1.5 in /extras/cloudstor/python/pre (from python-dateutil>=1.5->owslib) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /extras/cloudstor/python/pre (from requests>=1.0->owslib) (1.25.11)
# Requirement already satisfied: charset_normalizer~=2.0.0 in /extras/cloudstor/python/post (from requests>=1.0->owslib) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /cvmfs/sft.cern.ch/lcg/views/LCG_101swan/x86_64-centos7-gcc8-opt/lib/python3.9/site-packages (from requests>=1.0->owslib) (3.2)

# %% [markdown]
# Next, let's connect to a `WebFeatureService` using `OWSLib`. The [Open Geospatial Consortium](https://en.wikipedia.org/wiki/Open_Geospatial_Consortium) **Web Feature Service (WFS)** Interface Standard provides an interface allowing requests for geographical features across the web using platform-independent calls. More information about WFS, please check [ogc.org](https://www.ogc.org/standards/wfs) or [Wikipedia](https://en.wikipedia.org/wiki/Web_Feature_Service).

# %%
from owslib.wfs import WebFeatureService

# %% [markdown]
# In this step, we establish the API connection to the server. Here please insert your AURIN API credentials (username and password). If you don't have one, please apply your [AURIN API credentials] (website will be provided when it's ready).

# %%
WFS_USERNAME = '******'
WFS_PASSWORD= '******'
WFS_URL='https://eit-dev01.aurin.org.au/geoserver/ows?service=wfs'

# wfs11 = WebFeatureService(url=WFS_URL,username=WFS_USERNAME, password=WFS_PASSWORD, version='2.0.0')
# wfs11 = WebFeatureService(url=WFS_URL,username=WFS_USERNAME, password=WFS_PASSWORD, version='2.0.0')

# # OR
#wfs11 = WebFeatureService(url='http://services.land.vic.gov.au/catalogue/publicproxy/guest/dv_geoserver/wfs', version='2.0.0')

# %%
# Currently ADP can't be accessed through the cloud system, due to VPN is required in the developmental stage. 
# So the current Notebook is designed / tested by connecting to other open API. (ADP is tested working with local environment that connected to VPN)
wfs11 = WebFeatureService(url='http://services.land.vic.gov.au/catalogue/publicproxy/guest/dv_geoserver/wfs', version='2.0.0')

# %%
# (Optional) Check what operations are available
[operation.name for operation in wfs11.operations]
# Out:
# ['GetCapabilities',
#  'DescribeFeatureType',
#  'GetFeature',
#  'GetPropertyValue',
#  'ListStoredQueries',
#  'DescribeStoredQueries',
#  'CreateStoredQuery',
#  'DropStoredQuery',
#  'ImplementsBasicWFS',
#  'ImplementsTransactionalWFS',
#  'ImplementsLockingWFS',
#  'KVPEncoding',
#  'XMLEncoding',
#  'SOAPEncoding',
#  'ImplementsInheritance',
#  'ImplementsRemoteResolve',
#  'ImplementsResultPaging',
#  'ImplementsStandardJoins',
#  'ImplementsSpatialJoins',
#  'ImplementsTemporalJoins',
#  'ImplementsFeatureVersioning',
#  'ManageStoredQueries',
#  'PagingIsTransactionSafe',
#  'QueryExpressions']

# %% [markdown]
# # List contents of the service, i.e. list of available datasets.

# %% [markdown]
# (Here maybe the alternative is to add a function to use keyword to search datasets in ADP and display the relevant datasets. This is for discussion in the Working Group.)

# %%
contents = list(wfs11.contents)
contents
# Out:
# ['datavic:WATER_ISC2010_BANKFULL_WIDTH_R',
#  'datavic:WATER_ISC2010_BARE_GROUND',
#  'datavic:WATER_ISC2010_CHANNEL_TRANSECTS',
#  'datavic:WATER_ISC2010_FRAGMENTATION',
#  'datavic:WATER_ISC2010_LARGE_TREES',
#  'datavic:WATER_ISC2010_TOE_OF_BANK',
#  'datavic:WATER_ISC2010_TOP_OF_BANK',
#  'datavic:WATER_ISC2010_VEGETATION_OVERHANG',
#  'datavic:WATER_ISC2010_VEGETATION_WIDTH',
#  'datavic:WATER_ISC2010_WATER_BODIES',
#  'datavic:CATCHMENTS_BASIN100',
#  'datavic:VMADD_ADDRESS',
#  'datavic:VMCLTENURE_AGRICULTURAL',
#  'datavic:VMLITE_TR_AIRPORT',
#  'datavic:VMTRANS_AIRPORT_INFRASTRUCTURE',
#  'datavic:VMTRANS_AIRPORT_AREA_POLYGON',
#  'datavic:VMTRANS_AIR_INFRA_AREA_POLYGON',
#  'datavic:VMTRANS_TR_AIR_INFRA_POINT',
#  'datavic:WATER_BORES_BSE_ALL',
#  'datavic:MINERALS_SHALLD100_POLYGON',
#  'datavic:MINERALS_SHALLD100_ARC',
#  'datavic:CROWNLAND_PLMGEN_ALPINE_RESORT',
#  'datavic:CROWNLAND_PLM25_ALPINE_RESORT',
#  'datavic:VMPROP_ANNOTATION_TEXT',
#  'datavic:VMCLTENURE_APIARY',
#  'datavic:CROWNLAND_APIARY',
#  'datavic:WATER_AQUIFER_SAL_BASAL',
#  'datavic:WATER_AQUIFER_SAL_BED',
#  'datavic:WATER_AQUIFER_SAL_SHALLOW',
#  'datavic:VMHYDRO_WATER_AREA_INNUNDATION',
#  'datavic:CROWNLAND_HUNT25_CLOSED',
#  'datavic:CULTURE_SENSITIVITY_PUBLIC',
#  'datavic:VMTRANS_TR_ROAD_ARTERIAL',
#  'datavic:VMTRANS_ALPS_WALKING_TRACK',
#  'datavic:WATER_BFI_UNREG_RIVERS_1889_2012',
#  'datavic:WATER_BORES_BED_FA',
#  'datavic:WATER_BU_LTER',
#  'datavic:WATER_BU_MTER',
#  'datavic:WATER_BU_UTER',
#  'datavic:WATER_BU_WTABLE',
#  'datavic:VMTRANS_BICENTENNIAL_NATIONAL',
#  'datavic:VMTRANS_BIKE_BRIDGES',
#  'datavic:VMTRANS_TR_ROAD_BIKE_PATH',
#  'datavic:FLORAFAUNA1_NV2005_EVCBCS_D',
#  'datavic:FLORAFAUNA1_NV2005_EVCBCS_E',
#  'datavic:FLORAFAUNA1_NV2005_EVCBCS_LC',
#  'datavic:FLORAFAUNA1_NV2005_EVCBCS_R',
#  'datavic:FLORAFAUNA1_NV2005_EVCBCS_V',
#  'datavic:VMHYDRO_WATER_STRUCT_WELL',
#  'datavic:MINERALS_BORES_V_PUBLIC',
#  'datavic:FLORAFAUNA1_NV2005_EVCBCS_4_1',
#  'datavic:VMHYDRO_WATER_STRUCT_BREAKWATER',
#  'datavic:VMTRANS_TR_RAIL_BRIDGE',
#  'datavic:VMTRANS_TR_ROAD_BRIDGE',
#  'datavic:UDP_BH2016',
#  'datavic:VMFEAT_BUILDING_POINT',
#  'datavic:VMFEAT_BUILDING_POLYGON',
#  'datavic:VMFEAT_CFA_FIRE_STATION',
#  'datavic:VMPROP_CAD_AREA_BDY_L',
#  'datavic:CATCHMENTS_CMA100',
#  'datavic:VMHYDRO_WATER_STRUCT_CAUSEWAY',
#  'datavic:FLOOD_STRUCTURE_CHANNEL_OUTFALL',
#  'datavic:FLOOD_STRUCTURE_CHANNEL_REGULATOR',
#  'datavic:VMHYDRO_WATERCOURSE_CHANNEL',
#  'datavic:WATER_GW_BORES_CL',
#  'datavic:MINERALS_XSEC_COAL',
#  'datavic:MINERALS_COAL_BDY',
#  'datavic:MINERALS_COAL_ROOF',
#  'datavic:MINERALS_COAL_FLOOR',
#  'datavic:MINERALS_COAL_ISOPACH',
#  'datavic:MINERALS_COAL_RES',
#  'datavic:CATCHMENTS_COASTAL_ACID_SULPHATE_SOILS',
#  'datavic:CROWNLAND_PLMGEN_COASTAL_RES',
#  'datavic:CROWNLAND_PLM25_COASTAL_RES',
#  'datavic:FLORAFAUNA1_NV2005_EVCBCS_1_1',
#  'datavic:VMLITE_PUBLIC_LAND_COASTAL_W_SU3',
#  'datavic:VMLITE_PUBLIC_LAND_COASTAL_W_SU5',
#  'datavic:VMTRANS_TR_ROAD_COLLECTOR',
#  'datavic:CROWNLAND_PLMGEN_CMNWTH_LAND',
#  'datavic:CROWNLAND_PLM25_CMNWTH_LAND',
#  'datavic:CROWNLAND_PLMGEN_COMM_USE_AREA',
#  'datavic:CROWNLAND_PLM25_COMM_USE_AREA',
#  'datavic:VMHYDRO_WATERCOURSE_CONNECTOR',
#  'datavic:VMELEV_EL_CONTOUR',
#  'datavic:VMADMIN_CFA_DISTRICT',
#  'datavic:VMADMIN_CFA_REGION',
#  'datavic:VMADMIN_CFA_TFB_DISTRICT',
#  'datavic:FLOOD_STRUCTURE_CULVERT',
#  'datavic:MINERALS_PL',
#  'datavic:MINERALS_RL',
#  'datavic:WATER_DAM__',
#  'datavic:WATER_DAM',
#  'datavic:DISPLAY_VIEW_POLYGON',
#  'datavic:VMHYDRO_WATER_STRUCT_DAM_BATTER',
#  'datavic:VMHYDRO_WATER_STRUCT_DAM_WALL',
#  'datavic:VMHYDRO_WATER_STRUCT_DAM_WALL_ROAD',
#  'datavic:FLOOD_STRUCTURE_DAM_RESERVOIR',
#  'datavic:MINERALS_DLA',
#  'datavic:MINERALS_DLL',
#  'datavic:WATER_GEOL_SED_GOULBURN_MURRAY',
#  'datavic:VMVEG_TREE_DENSITY_DENSE',
#  'datavic:VMADMIN_DEPI_REGION',
#  'datavic:VMADMIN_DELWP_REGION',
#  'datavic:VMADMIN_DSE_REGION',
#  'datavic:PLANNING_BUSHFIRE_PRONE_AREA',
#  'datavic:WATER_PWSC100',
#  'datavic:VMTRANS_TR_RAIL_DISMANTLED',
#  'datavic:VMTRANS_TR_RAIL_DISUSED',
#  'datavic:VMHYDRO_WATERCOURSE_DRAIN',
#  'datavic:FLOOD_STRUCTURE_DRAIN_OUTFALL',
#  'datavic:FLOOD_STRUCTURE_DRAIN_REGULATOR',
#  'datavic:FLORAFAUNA1_NV2005_EVCBCS_6_1',
#  'datavic:FLORAFAUNA1_NV2005_EVCBCS_6_2',
#  'datavic:VMTRANS_TR_ROAD_DWO',
#  'datavic:MINERALS_DURI100_POLYGON',
#  'datavic:ENERGY_ELECTRICITY_DISTRIBUTOR',
#  'datavic:EMERGENCY_MANAGEMENT_REGION',
#  'datavic:ENERGY_FACILITIES',
#  'datavic:ENVIRONPROTECT_ENVIRO_AUDIT_LOC_POINT',
#  'datavic:ENVIRONPROTECT_ENVIRO_AUDIT_LOC_POLYGON',
#  'datavic:ENVIRONPROTECT_GQRUZ_POINT',
#  'datavic:ENVIRONPROTECT_GQRUZ_POLYGON',
#  'datavic:ENVIRONPROTECT_EPA_LICENCE_POINT',
#  'datavic:ENVIRONPROTECT_EPA_LICENCE_POLYGON',
#  'datavic:ENVIRONPROTECT_PSR_POINT',
#  'datavic:ENVIRONPROTECT_PSR_POLYGON',
#  'datavic:ENVIRONPROTECT_VLR_POINT',
#  'datavic:ENVIRONPROTECT_VLR_POLYGON',
#  'datavic:CROWNLAND_PLMGEN_EARTH_RESOURCES',
#  'datavic:CROWNLAND_PLM25_EARTH_RESOURCES',
#  'datavic:VMPROP_EASEMENT',
#  'datavic:VMFEAT_EMERGENCY_FACILITY',
#  'datavic:WATER_EWSP',
#  'datavic:CROWNLAND_PLMGEN_NAT_CATCH',
#  'datavic:CROWNLAND_PLM25_NAT_CATCH',
#  'datavic:WATER_ESTUARIES',
#  'datavic:WATER_EST_CATCH',
#  'datavic:MINERALS_EWAHST',
#  'datavic:MINERALS_MINHST',
#  'datavic:MINERALS_GRAT100KM',
#  'datavic:MINERALS_GRAT10KM',
#  'datavic:MINERALS_GRAT1KM',
#  'datavic:MINERALS_EL',
#  'datavic:MINERALS_ELHIST',
#  'datavic:MINERALS_MP',
#  'datavic:MINERALS_EIIA',
#  'datavic:MINERALS_EWA',
#  'datavic:FIRE_HISTORY_FREQUENCY',
#  'datavic:WATER_FLOWS_RIVER_REACHES',
#  'datavic:VMFEAT_FOI_LINE',
#  'datavic:VMFEAT_FOI_POINT',
#  'datavic:VMFEAT_FOI_POLYGON',
#  'datavic:VMFEAT_FOI_INDEX_CENTROID',
#  'datavic:VMFEAT_FOI_INDEX_EXTENT',
#  'datavic:FRV_RESPONSE_AREA',
#  'datavic:WATER_FARM_DAMS',
#  'datavic:WATER_FARM_DAMS_POINT',
#  'datavic:FIRE_FIRE_HISTORY',
#  'datavic:FRV_DISTRICT',
#  'datavic:FRV_LEGISLATED_BOUNDARY',
#  'datavic:FRV_REGION',
#  'datavic:FLOOD_STRUCTURE_FLOOD_EFFLUENT',
#  'datavic:FLOOD_STRUCTURE',
#  'datavic:FLOOD_STRUCTURE_FLOOD_REGUULATOR',
#  'datavic:WATER_EST_FLUV',
#  'datavic:VMTRANS_TR_ROAD_FOOTBRIDGE',
#  'datavic:VMTRANS_TR_ROAD_FORDS',
#  'datavic:FORESTS_FCOV1000_1869_ABSENT',
#  'datavic:FORESTS_FCOV500_72_ABSENT',
#  'datavic:FORESTS_FCOV500_87_ABSENT',
#  'datavic:FORESTS_FCOV1000_1869_PRESENT',
#  'datavic:FORESTS_FCOV500_72_PRESENT',
#  'datavic:FORESTS_FCOV500_87_PRESENT',
#  'datavic:CROWNLAND_PLMGEN_FOREST_PARK',
#  'datavic:CROWNLAND_PLM25_FOREST_PARK',
#  'datavic:MINERALS_FOSSILS',
#  'datavic:VMINDEX_FR_FRAMEWORK_AREA_LINE',
#  'datavic:VMINDEX_FR_FRAMEWORK_AREA_POLYGON',
#  'datavic:VMTRANS_TR_ROAD_FREEWAY',
#  'datavic:MINERALS_GSVMI',
#  'datavic:MINERALS_PIPELINE',
#  'datavic:VMTRANS_GATE',
#  'datavic:VMCLTENURE_GENERAL',
#  'datavic:MINERALS_ALTERN100_POLYGON',
#  'datavic:MINERALS_BASINS',
#  'datavic:MINERALS_CHERTH100_POLYGON',
#  'datavic:MINERALS_DEEPLD100_POLYGON',
#  'datavic:MINERALS_DEEPLD250_POLYGON',
#  'datavic:MINERALS_DEEPLD100_ARC',
#  'datavic:MINERALS_GEXCURS',
#  'datavic:MINERALS_FACIES100_POLYGON',
#  'datavic:MINERALS_FLTROCK100_POLYGON',
#  'datavic:MINERALS_GOLDFLD100_POLYGON',
#  'datavic:MINERALS_GEOL1M_ARC',
#  'datavic:MINERALS_GEOL250_ARC',
#  'datavic:MINERALS_OUTCROP',
#  'datavic:MINERALS_GEOL1M_POLYGON',
#  'datavic:MINERALS_GEOL100_POLYGON',
#  'datavic:MINERALS_GEOL250_POLYGON',
#  'datavic:MINERALS_GEOL4M_POLYGON',
#  'datavic:MINERALS_GEOL100_ARC',
#  'datavic:STRUCM100',
#  'datavic:MINERALS_STRUC',
#  'datavic:WATER_GEOL_STRUCT_GOULBURN_MURRAY',
#  'datavic:WATER_GEOL_STRUCT_OVENS_VALLEY',
#  'datavic:MINERALS_SIGFEAT',
#  'datavic:VMFEAT_GEOMARK_INDEX_CENTROID',
#  'datavic:VMFEAT_GEOMARK_INDEX_EXTENT',
#  'datavic:VMFEAT_GEOMARK_LINE',
#  'datavic:VMFEAT_GEOMARK_POINT',
#  'datavic:VMFEAT_GEOMARK_POLYGON',
#  'datavic:CATCHMENTS_GMU250',
#  'datavic:MINERALS_GPMISCL100',
#  'datavic:MINERALS_GPMISCL250',
#  'datavic:MINERALS_GPSTRLINE100',
#  'datavic:MINERALS_GPSTRLINE250',
#  'datavic:MINERALS_GMLHST',
#  'datavic:MINERALS_NUGGET',
#  'datavic:VMCLTENURE_GOV_ROAD_POLY',
#  'datavic:MINERALS_GRAVITY',
#  'datavic:VMTRANS_GREAT_DIVIDING_TRAIL',
#  'datavic:VMELEV_EL_GRND_SURFACE_POINT',
#  'datavic:VMELEV_EL_GRND_TYPE_POINT',
#  'datavic:WATER_GC',
#  'datavic:WATER_GMA_SUBZONE',
#  'datavic:WATER_GMA_ZONE',
#  'datavic:WATER_GMA',
#  'datavic:WATER_GMB',
#  'datavic:WATER_GWR',
#  'datavic:WATER_GW_SITES',
#  'datavic:WATER_GW_SW_INTERACTION',
#  'datavic:WATER_GW_SW_INTERACTION_FLUX',
#  'datavic:FLORAFAUNA1_NV2005_EVCBCS_16_2',
#  'datavic:FLORAFAUNA1_NV2005_EVCBCS_16_1',
#  'datavic:FLORAFAUNA1_NV2005_EVCBCS_16_3',
#  'datavic:FLORAFAUNA1_NV2005_EVCBCS_2_2',
#  'datavic:FLORAFAUNA1_NV2005_EVCBCS_2_1',
#  'datavic:FLORAFAUNA1_NV2005_EVCBCS_15_1',
#  'datavic:FLORAFAUNA1_NV2005_EVCBCS_15_2',
#  'datavic:VMTRANS_TR_ROAD_HIGHWAY',
#  'datavic:MINERALS_SHAFT',
#  'datavic:CROWNLAND_PLM25_H_A_C_FEAT_RES',
#  'datavic:CROWNLAND_PLMGEN_H_A_C_FEAT_RES',
#  'datavic:ENVIRONPROTECT_SANDS_MCDOUGALL_PUBLIC',
#  'datavic:WATER_IRRIGATION_SYSTEM_ALLOCATION_',
#  'datavic:WATER_IRRIGATION_SYSTEM_ALLOCATION',
#  'datavic:WATER_ISC_REACH',
#  'datavic:WATER_FAULTS_LATROBE_GP',
#  'datavic:WATER_FAULTS_NWMURRAY_BASIN',
#  'datavic:WATER_FAULTS_GOLDEN_BEACH_FM',
#  'datavic:WATER_FAULTS_STRZELECKI_GP',
#  'datavic:WATER_FAULTS_WANGERRIP_GP',
#  'datavic:WATER_IRRIGATION_DISTRICT',
#  'datavic:VMHYDRO_WATER_AREA_LAKES_DAMS',
#  'datavic:MINERALS_EXC',
#  'datavic:CATCHMENTS_LSYS100',
#  'datavic:CATCHMENTS_LSYS250',
#  'datavic:CATCHMENTS_BIOLINK500',
#  'datavic:CATCHMENTS_FLAGSHIP500',
#  'datavic:VMHYDRO_WATER_STRUCT_RAMP',
#  'datavic:VMCLTENURE_LEASE',
#  'datavic:VMTRANS_LEVEL_CROSSING',
#  'datavic:VMTRANS_TR_RAIL_LIGHT',
#  'datavic:WATER_LINEAMENTS_GRAVITY',
#  'datavic:WATER_LINEAMENTS_RADIO',
#  'datavic:WATER_LINEAMENTS_TMI',
#  'datavic:MINERALS_STRLINE1M',
#  'datavic:MINERALS_STRLINE100',
#  'datavic:MINERALS_STRLINE250',
#  'datavic:VMADMIN_LGA_POLYGON',
#  'datavic:VMADMIN_AD_LGA_AREA_POLYGON',
#  'datavic:VMLITE_LGA',
#  'datavic:VMADMIN_SHIRE500_1994',
#  'datavic:VMTRANS_TR_ROAD_LOCAL',
#  'datavic:VMADMIN_LOCALITY_POLYGON',
#  'datavic:VMADMIN_AD_LOCALITY_AREA_POLYGON',
#  'datavic:VMLITE_LOCALITY_POLYGON',
#  'datavic:VMFEAT_LOCALITY_POINT',
#  'datavic:VMHYDRO_WATER_STRUCT_LOCK',
#  'datavic:FLORAFAUNA1_NV2005_EVCBCS_5_2',
#  'datavic:FLORAFAUNA1_NV2005_EVCBCS_5_3',
#  'datavic:FLORAFAUNA1_NV2005_EVCBCS_5_1',
#  'datavic:FLORAFAUNA1_NV2005_EVCBCS_3_1',
#  'datavic:WATER_MELBOURNE_WATER_CORP',
#  'datavic:WATER_MELBOURNE_WATER_RETAILER',
#  'datavic:UDP_MAJOR_INFILL2009',
#  'datavic:UDP_MAJOR_INFILL2011',
#  'datavic:UDP_MRS2016',
#  'datavic:FLORAFAUNA1_NV2005_EVCBCS_17_2',
#  'datavic:FLORAFAUNA1_NV2005_EVCBCS_17_3',
#  'datavic:FLORAFAUNA1_NV2005_EVCBCS_17_4',
#  'datavic:FLORAFAUNA1_NV2005_EVCBCS_17_1',
#  'datavic:VMTRANS_TR_ROAD_MANAGEMENT_VEHICLES',
#  'datavic:FLORAFUANA1_SWOOPING_BIRD',
#  'datavic:VMHYDRO_WATER_STRUCT_MARINA',
#  'datavic:CROWNLAND_PLMGEN_MARINE_NP',
#  'datavic:CROWNLAND_PLM25_MARINE_NP',
#  'datavic:VMLITE_PUBLIC_LAND_MARINE_PARKRES_SU3',
#  'datavic:VMLITE_PUBLIC_LAND_MARINE_PARKRES_SU5',
#  'datavic:CROWNLAND_PLMGEN_MARINE_SANC',
#  'datavic:CROWNLAND_PLM25_MARINE_SANC',
#  'datavic:VMTRANS_TR_RAIL_MARSHALLING',
#  'datavic:VMVEG_TREE_DENSITY_MEDIUM',
#  'datavic:MTP_EES_FUTURE_STN_ENTRANCES',
#  'datavic:MTP_EES_STATION_ENTRANCES',
#  'datavic:MTP_EES_TUNNEL_ENTRANCES',
#  'datavic:MTP_EES_UNDERGROUND_RAIL_TRACK',
#  'datavic:MTP_EES_UNDERGROUND_STATIONS',
#  'datavic:VMELEV_EL_CONTOUR_1TO5M',
#  'datavic:VMELEV_EL_GRND_SURFACE_POINT_1TO5M',
#  'datavic:VMADMIN_MFB_DISTRICT',
#  'datavic:VMADMIN_MFB_REGION',
#  'datavic:MINERALS_MINERAL',
#  'datavic:MINERALS_MINERALP',
#  'datavic:MINERALS_MINSITE',
#  'datavic:MINERALS_SPRINGS',
#  'datavic:MINERALS_MINTEN',
#  'datavic:MINERALS_SITES',
#  'datavic:MINERALS_INSPECT',
#  'datavic:MINERALS_MIN',
#  'datavic:UDP_MINOR_INFILL_SUPPLY2009',
#  'datavic:MINERALS_MISCL100',
#  'datavic:MINERALS_MISCL250',
#  'datavic:WATER_MODIFIED_RIVERS',
#  'datavic:WATER_DW_POINTS',
#  'datavic:FLORAFAUNA1_NV1750_EVCBCS_10_1',
#  'datavic:FLORAFAUNA1_NV2005_EVCBCS_10_1',
#  'datavic:FLORAFAUNA1_NV1750_EVCBCS_10_2',
#  'datavic:FLORAFAUNA1_NV2005_EVCBCS_10_2',
#  'datavic:CROWNLAND_PLMGEN_NPA_SHED_3',
#  'datavic:CROWNLAND_PLM25_NPA_SHED_3',
#  'datavic:CROWNLAND_PLMGEN_NPA_SHED_4',
#  'datavic:CROWNLAND_PLM25_NPA_SHED_4',
#  'datavic:NV2005_FFG_COMM',
#  'datavic:CROWNLAND_PLMGEN_NATIONAL_P',
#  'datavic:CROWNLAND_PLM25_NATIONAL_P',
#  'datavic:FLORAFAUNA1_NV1750_EVCBCS',
#  'datavic:FLORAFAUNA1_NV2005_EVCBCS',
#  'datavic:CROWNLAND_PLMGEN_NATURAL_FEAT',
#  'datavic:CROWNLAND_PLM25_NATURAL_FEAT',
#  'datavic:CROWNLAND_PLMGEN_NATURE_CONSERV',
#  'datavic:CROWNLAND_PLM25_NATURE_CONSERV',
#  'datavic:FLOOD_STRUCTURE_OCCUPATION_CROSSING',
#  'datavic:MINERALS_FACILITY',
#  'datavic:MINERALS_OILGAS',
#  'datavic:MINERALS_ANASURV',
#  'datavic:MINERALS_DIGSURV',
#  'datavic:VMTRANS_TR_RAIL_OPERATIONAL',
#  'datavic:CROWNLAND_PLMGEN_OTHER',
#  'datavic:FLOOD_STRUCTURE_OTHER_BRIDGE',
#  'datavic:VMLITE_PUBLIC_LAND_OTHER_SU3',
#  'datavic:VMLITE_PUBLIC_LAND_OTHER_SU5',
#  'datavic:CROWNLAND_PLM25_OTHER',
#  'datavic:FORESTS_PAIM_VM_TR_ROAD_CLOSURES',
#  'datavic:VMPLAN_PLAN_ZONE',
#  'datavic:PTV_METRO_BUS_ROUTE',
#  'datavic:PTV_METRO_BUS_STOP',
#  'datavic:PTV_METRO_TRAIN_STATION',
#  'datavic:PTV_METRO_TRAM_ROUTE',
#  'datavic:PTV_METRO_TRAM_STOP',
#  'datavic:PTV_REGIONAL_BUS_ROUTE',
#  'datavic:PTV_REGIONAL_BUS_STOP',
#  'datavic:PTV_REGIONAL_COACH_ROUTE',
#  'datavic:PTV_REGIONAL_COACH_STOP',
#  'datavic:PTV_REGIONAL_TRAIN_STATION',
#  'datavic:PTV_SKYBUS_ROUTE',
#  'datavic:PTV_SKYBUS_STOP',
#  'datavic:PTV_TRAIN_CARPARK',
#  'datavic:PTV_TRAIN_CORRIDOR_CENTRELINE',
#  'datavic:PTV_TRAIN_STATION_BIKE_STORAGE',
#  'datavic:PTV_TRAIN_STATION_PLATFORM',
#  'datavic:PTV_TRAIN_TRACK_CENTRELINE',
#  'datavic:PTV_TRAM_TRACK_CENTRELINE',
#  'datavic:VMPROP_PARCEL_PROPERTY',
#  'datavic:VMPROP_PARCEL_MP',
#  'datavic:VMPROP_PARCEL_MP_ALL',
#  'datavic:VMPROP_PARCEL_VIEW',
#  'datavic:VMADMIN_PARISH_POLYGON',
#  'datavic:CROWNLAND_PARKRES',
#  'datavic:VMLITE_PUBLIC_LAND_PARKRES_SU3',
#  'datavic:VMLITE_PUBLIC_LAND_PARKRES_SU5',
#  'datavic:WATER_GEOL_BSE_PERMIAN',
#  'datavic:MINERALS_PETROLPRO',
#  'datavic:MINERALS_GRATMIN',
#  'datavic:MINERALS_PETROL',
#  'datavic:MINERALS_PET_WELLS',
#  'datavic:MINERALS_PETPHYS',
#  'datavic:VMHYDRO_WATER_STRUCT_PIPE',
#  'datavic:VMCLTENURE_PIPELINES',
#  'datavic:VMFEAT_PL_PLACE_AREA_POLYGON',
#  'datavic:VMLITE_LOCALITY',
#  'datavic:FLORAFAUNA1_NV2005_EVCBCS_12_1',
#  'datavic:FLORAFAUNA1_NV2005_EVCBCS_13_1',
#  'datavic:FLORAFAUNA1_NV2005_EVCBCS_13_3',
#  'datavic:FLORAFAUNA1_NV2005_EVCBCS_13_2',
#  'datavic:FLORAFAUNA1_NV2005_EVCBCS_13_4',
#  'datavic:FIRE_BURNPLAN13',
#  'datavic:BURNPLAN21',
#  'datavic:VMPLAN_PLAN_UGA',
#  'datavic:VMPLAN_PLAN_UGB',
#  'datavic:VMPLAN_PLAN_CODELIST',
#  'datavic:VMPLAN_PLAN_OVERLAY',
#  'datavic:CROWNLAND_PLMGEN_PLANTATION',
#  'datavic:CROWNLAND_PLM25_PLANTATION',
#  'datavic:VMFEAT_POLICE_STATION',
#  'datavic:VMHYDRO_WATER_AREA_PONDAGE',
#  'datavic:CROWNLAND_PLMGEN_PORT_COAST_FAC',
#  'datavic:CROWNLAND_PLM25_PORT_COAST_FAC',
#  'datavic:PORT_PHILLIP_AIDS_TO_NAV',
#  'datavic:VMADMIN_POSTCODE_POLYGON',
#  'datavic:VMLITE_POSTCODE_POLYGON',
#  'datavic:WATER_GDE_TERR_CORCMA',
#  'datavic:WATER_GDE_TERR_EGCMA',
#  'datavic:WATER_GDE_TERR_GHCMA',
#  'datavic:WATER_GDE_TERR_GBCMA',
#  'datavic:WATER_GDE_TERR_MCMA',
#  'datavic:WATER_GDE_TERR_NCCMA',
#  'datavic:WATER_GDE_TERR_NECMA',
#  'datavic:WATER_GDE_TERR_PPCMA',
#  'datavic:WATER_GDE_TERR_WGCMA',
#  'datavic:WATER_GDE_TERR_WCMA',
#  'datavic:WATER_GW_FLOW_IMPACT_STRUCT',
#  'datavic:PPTN_LINES',
#  'datavic:PPTN_POINTS',
#  'datavic:WATER_PRIORITY_RIVERS',
#  'datavic:VMTRANS_TR_ROAD_PRIVATE',
#  'datavic:VMPROP_PROPERTY_MP',
#  'datavic:VMPROP_PROPERTY_MP_ALL',
#  'datavic:VMPROP_PROPERTY_VIEW',
#  'datavic:CROWNLAND_PLMGEN_PROP_NPA',
#  'datavic:CROWNLAND_PLM25_PROP_NPA',
#  'datavic:VMTRANS_TR_ROAD_PROPOSED',
#  'datavic:CROWNLAND_PLM25',
#  'datavic:CROWNLAND_PLMGEN',
#  'datavic:CROWNLAND_PLM25_OVERLAYS',
#  'datavic:CROWNLAND_PLM25_OVERLAYS_HR',
#  'datavic:CROWNLAND_PLM25_OVERLAYS_RA',
#  'datavic:CROWNLAND_PLM25_OVERLAYS_RNA',
#  'datavic:CROWNLAND_PLM25_OVERLAYS_NCA',
#  'datavic:CROWNLAND_PLM25_OVERLAYS_WZ',
#  'datavic:FORESTS_RAINFOR25_MURRUNGOWAR',
#  'datavic:RESOURCEFOOTPRINT',
#  'datavic:WATER_RURAL_WATER_CORP',
#  'datavic:VMTRANS_TR_RAIL_INFRASTRUCTURE',
#  'datavic:VMTRANS_TR_RAIL',
#  'datavic:VMTRANS_TR_RAIL_SIDING',
#  'datavic:VMTRANS_RAIL_STATION_OPERATIONAL',
#  'datavic:VMTRANS_RAIL_STATION_DISMANTLED',
#  'datavic:VMTRANS_RAIL_STATION_DISUSED',
#  'datavic:VMTRANS_TR_RAIL_TRAIL',
#  'datavic:VMTRANS_TR_RAIL_TUNNEL',
#  'datavic:FLOOD_STRUCTURE_RAILWAY_BRIDGE',
#  'datavic:FLORAFAUNA1_NV2005_EVCBCS_9_1',
#  'datavic:FLORAFAUNA1_RAMSAR25',
#  'datavic:FORESTS_RECWEB_ASSET',
#  'datavic:FORESTS_RECWEB_CARPARK',
#  'datavic:FORESTS_RECWEB_HISTORIC_RELIC',
#  'datavic:FORESTS_RECWEB_HUT',
#  'datavic:FORESTS_RECWEB_POI',
#  'datavic:FORESTS_RECWEB_SITE',
#  'datavic:FORESTS_RECWEB_TRACK',
#  'datavic:CROWNLAND_PLMGEN_REGIONAL_P',
#  'datavic:CROWNLAND_PLM25_REGIONAL_P',
#  'datavic:VMFEAT_GNR',
#  'datavic:CULTURE_RAP',
#  'datavic:MINERALS_RRDURI100_ARC',
#  'datavic:MINERALS_RRDURI100_POLYGON',
#  'datavic:MINERALS_RRRADSIG100_POLYGON',
#  'datavic:MINERALS_RRRADSIG100_ARC',
#  'datavic:MINERALS_RRREGO100_ARC',
#  'datavic:MINERALS_RRREGO100_POLYGON',
#  'datavic:VMCLTENURE_RESERVE_MANAGEMENT',
#  'datavic:VMCLTENURE_RESERVE_STATUS',
#  'datavic:FLOOD_STRUCTURE_RETARDING_BASIN',
#  'datavic:FLORAFAUNA1_NV2005_EVCBCS_8_1',
#  'datavic:FLORAFAUNA1_NV2005_EVCBCS_8_2',
#  'datavic:FLORAFAUNA1_NV2005_EVCBCS_14_1',
#  'datavic:FLORAFAUNA1_NV2005_EVCBCS_14_2',
#  'datavic:VMHYDRO_WATERCOURSE_RIVER',
#  'datavic:FLOOD_STRUCTURE_ROAD_BRIDGE',
#  'datavic:VMPROP_ROAD_CASEMENT_POLYGON',
#  'datavic:FLOOD_STRUCTURE_ROAD_EMBANKMENT',
#  'datavic:VMTRANS_TR_ROAD',
#  'datavic:VMTRANS_TR_FERRY_ROUTE',
#  'datavic:VMTRANS_TR_ROAD_4WD',
#  'datavic:VMTRANS_TR_ROAD_TRACKS',
#  'datavic:VMTRANS_TR_ROAD_CLOSED',
#  'datavic:VMTRANS_TR_ROAD_LIMITS',
#  'datavic:VMTRANS_TR_ROAD_TUNNEL',
#  'datavic:VMTRANS_TR_ROAD_UNMAINTAINED',
#  'datavic:VMELEV_GROUND_TYPE_ROCK_OC',
#  'datavic:MINERALS_ROCKS',
#  'datavic:FLORAFAUNA1_NV2005_EVCBCS_20_1',
#  'datavic:VMTRANS_ROUNDABOUT',
#  'datavic:VMHYDRO_WATER_AREA_SALT_LAKE',
#  'datavic:VMHYDRO_WATER_AREA_SALT_PAN',
#  'datavic:FLORAFAUNA1_NV2005_EVCBCS_19_2',
#  'datavic:FLORAFAUNA1_NV2005_EVCBCS_19_1',
#  'datavic:VMELEV_GROUND_TYPE_SAND',
#  'datavic:VMVEG_TREE_DENSITY_SCATTERED',
#  'datavic:WATER_BORES_SED_FA',
#  'datavic:MINERALS_SEISMIC_ARC',
#  'datavic:MINERALS_SEISMIC_POINT',
#  'datavic:CROWNLAND_PLMGEN_SERVICE_UTIL',
#  'datavic:CROWNLAND_PLM25_SERVICE_UTIL',
#  'datavic:VMHYDRO_WATER_AREA_SEWAGE',
#  'datavic:MINERALS_SHALWK100_POLYGON',
#  'datavic:MINERALS_SHALWK100_ARC',
#  'datavic:VMLITE_VICTORIA_POLYGON_SU5',
#  'datavic:VMLITE_PUBLIC_LAND_SOFTWOOD_SU3',
#  'datavic:VMLITE_PUBLIC_LAND_SOFTWOOD_SU5',
#  'datavic:VMHYDRO_WATER_STRUCT_SPILLWAY',
#  'datavic:VMFEAT_GEOMARK_SPORT_FACILITY_POLY',
#  'datavic:WATER_SPRING_LOCATIONS',
#  'datavic:VMLITE_PUBLIC_LAND_STATE_FOREST_SU3',
#  'datavic:VMLITE_PUBLIC_LAND_STATE_FOREST_SU5',
#  'datavic:CROWNLAND_PLMGEN_STATE_FOREST',
#  'datavic:CROWNLAND_PLM25_STATE_FOREST',
#  'datavic:CROWNLAND_PLMGEN_STATE_PARK',
#  'datavic:CROWNLAND_PLM25_STATE_PARK',
#  'datavic:VMLITE_FOREST_SU3',
#  'datavic:VMLITE_FOREST_SU5',
#  'datavic:VMLITE_FOREST_SU2',
#  'datavic:VMLITE_GEO_AREA_LABEL',
#  'datavic:VMLITE_GEO_POINT_LABEL',
#  'datavic:VMLITE_BUILT_UP_AREA',
#  'datavic:VMLITE_PUBLIC_LAND_SU3',
#  'datavic:VMLITE_PUBLIC_LAND_SU5',
#  'datavic:VMLITE_TR_RAIL',
#  'datavic:VMLITE_TR_RAIL_STATION',
#  'datavic:VMLITE_TR_ROAD',
#  'datavic:VMLITE_HY_WATER_AREA',
#  'datavic:VMLITE_HY_WATERCOURSE',
#  'datavic:STEER_CLEAR_AREA',
#  'datavic:VMHYDRO_WATERCOURSE_STREAM',
#  'datavic:FORESTS_SVEG100',
#  'datavic:VMTRANS_TR_ROAD_SUB_A',
#  'datavic:FLORAFAUNA1_NV1750_EVCBCS_11_1',
#  'datavic:FLORAFAUNA1_NV1750_EVCBCS_11_2',
#  'datavic:FLORAFAUNA1_NV2005_EVCBCS_11_1',
#  'datavic:FLORAFAUNA1_NV2005_EVCBCS_11_2',
#  'datavic:MINERALS_GPSGEOL1100_POLYGON',
#  'datavic:VMTRANS_TR_ROAD_SEASONAL',
#  'datavic:VMTRANS_SURF_COAST_WALK',
#  'datavic:MINERALS_GCHEM',
#  'datavic:SMES_FULL',
#  'datavic:WATER_SDL_BASEFLOWS',
#  'datavic:WATER_SDL_CATCH',
#  'datavic:VMHYDRO_WATER_AREA_SWAMPS',
#  'datavic:FLOOD_STRUCTURE_SYPHON',
#  'datavic:TR_ROAD_REGISTER',
#  'datavic:MINERALS_TLHST',
#  'datavic:VMHYDRO_HY_WATER_STRUCT_AREA_TANK',
#  'datavic:VMCLTENURE_CL_TENURE_VIEW',
#  'datavic:VMTRANS_TR_ROAD_TOLLWAYS',
#  'datavic:VMADMIN_TOWNSHIP_POLYGON',
#  'datavic:VMTRANS_TR_RAIL_TRAM',
#  'datavic:WATER_URBAN_WATER_CORP',
#  'datavic:CROWNLAND_PLMGEN_UNCAT_PUBLIC',
#  'datavic:CROWNLAND_PLM25_UNCAT_PUBLIC',
#  'datavic:VMHYDRO_WATER_STRUCT_UG_PIPE',
#  'datavic:VMTRANS_TR_RAIL_UNDERGROUND',
#  'datavic:UDP_IND2016',
#  'datavic:UDP_IND2016_PROPOSED_AREAS',
#  'datavic:PUBLICLANDUSE_VEAC_METRO_OPEN_SPACE',
#  'datavic:FORESTS_VICFORESTS_ALLOCATION_APR2019',
#  'datavic:VMCLTENURE_V_CL_TENURE_POLY',
#  'datavic:VMINDEX_VICMAP_MAPINDEX_SPECIAL',
#  'datavic:VMINDEX_VICMAP_MAPINDEX_25D',
#  'datavic:VMINDEX_VICMAP_MAPINDEX_25S',
#  'datavic:VMINDEX_VICMAP_MAPINDEX_30DA3',
#  'datavic:VMINDEX_VICMAP_MAPINDEX_30SA4',
#  'datavic:VMINDEX_VICMAP_MAPINDEX_50D',
#  'datavic:VMINDEX_VICMAP_MAPINDEX_50S',
#  'datavic:VMPROP_PROPERTY_ADDRESS',
#  'datavic:VMINDEX_VICMAP_MAPINDEX_100D',
#  'datavic:VMVEG_TREE_DENSITY',
#  'datavic:FLOOD_FLOODWAY',
#  'datavic:FLOOD_FLOW_DIRECTION',
#  'datavic:FLOOD_CONTOUR_20Y_ARI',
#  'datavic:FLOOD_CONTOUR_50Y_ARI',
#  'datavic:FLOOD_CONTOUR_10Y_ARI',
#  'datavic:FLOOD_CONTOUR_100Y_ARI',
#  'datavic:FLOOD_CONTOUR_200Y_ARI',
#  'datavic:FLOOD_CONTOUR_5Y_ARI',
#  'datavic:FLOOD_CONTOUR_500Y_ARI',
#  'datavic:FLOOD_EXTENT_PMF',
#  'datavic:FLOOD_EXTENT_10Y_ARI',
#  'datavic:FLOOD_EXTENT_100Y_ARI',
#  'datavic:FLOOD_EXTENT_1000Y_ARI',
#  'datavic:FLOOD_EXTENT_200Y_ARI',
#  'datavic:FLOOD_EXTENT_30Y_ARI',
#  'datavic:FLOOD_EXTENT_5Y_ARI',
#  'datavic:FLOOD_EXTENT_50Y_ARI',
#  'datavic:FLOOD_EXTENT_500Y_ARI',
#  'datavic:VBA_RESTRICTED_1M',
#  'datavic:FLORAFAUNA1_VBIOREG100',
#  'datavic:VIC_RAILWAY_DISUSED',
#  'datavic:VMADMIN_AD_VICGOV_REGION',
#  'datavic:VMADMIN_VICGOV_REGION',
#  'datavic:PLANNING_HERITAGE_INVENTORY',
#  'datavic:PLANNING_HERITAGE_REGISTER',
#  'datavic:CATCHMENTS_LANDUSE_2014',
#  'datavic:VMADMIN_STATE_ASSEMBLY_2001',
#  'datavic:VMADMIN_STATE_ASSEMBLY_2013',
#  'datavic:STATE_ASSEMBLY_2022',
#  'datavic:VIC_RAIL_TRAILS',
#  'datavic:VIC_RAILWAY_CORRIDOR',
#  'datavic:VIC_RAILWAY_STATIONS',
#  'datavic:SOIL_TYPE',
#  'datavic:VIC_TOURIST_RAIL_CORRIDOR',
#  'datavic:VMADMIN_STATE_COUNCIL_2005',
#  'datavic:VMADMIN_STATE_COUNCIL_2013',
#  'datavic:STATE_COUNCIL_2022',
#  'datavic:FLORAFAUNA1_WETLAND_1994',
#  'datavic:FLORAFAUNA1_WETLANDDIR',
#  'datavic:WATER_BORES_VOLC_FA',
#  'datavic:MINERALS_ERUPTION_PTS',
#  'datavic:VMADMIN_WARD_2008',
#  'datavic:VMADMIN_WARD_2012',
#  'datavic:VMADMIN_WARD_2016',
#  'datavic:WARD_2017',
#  'datavic:VMADMIN_WARD_2020',
#  'datavic:WATER_CORP',
#  'datavic:WATER_STORAGE',
#  'datavic:WATER_STORAGE_',
#  'datavic:VMTRANS_WALKING_TRACK',
#  'datavic:VMHYDRO_HY_WATER_AREA_POLYGON',
#  'datavic:CROWNLAND_PLMGEN_WATER_BODY',
#  'datavic:CROWNLAND_PLM25_WATER_BODY',
#  'datavic:VMHYDRO_HY_WATER_POINT',
#  'datavic:CROWNLAND_PLMGEN_WATER_PROD',
#  'datavic:CROWNLAND_PLM25_WATER_PROD',
#  'datavic:VMHYDRO_HY_WATER_STRUCT_POINT',
#  'datavic:WATER_WSPA_ZONE',
#  'datavic:WATER_WSPA',
#  'datavic:VMHYDRO_WATER_STRUCT_TANK',
#  'datavic:VMHYDRO_HY_WATERCOURSE',
#  'datavic:VMHYDRO_WATERFALL',
#  'datavic:VMHYDRO_WATER_STRUCT_WATER_PLACE',
#  'datavic:FLOOD_STRUCTURE_WEIR',
#  'datavic:FLORAFAUNA1_NV2005_EVCBCS_7_2',
#  'datavic:FLORAFAUNA1_NV2005_EVCBCS_7_1',
#  'datavic:FLORAFAUNA1_WETLAND500',
#  'datavic:FLORAFAUNA1_WETLAND_LANDSCAPE',
#  'datavic:FLORAFAUNA1_NV2005_EVCBCS_18_2',
#  'datavic:FLORAFAUNA1_NV2005_EVCBCS_18_1',
#  'datavic:FLORAFAUNA1_WETLAND_1788',
#  'datavic:VMHYDRO_WATER_STRUCT_WHARF',
#  'datavic:CROWNLAND_PLMGEN_WILDERNESS',
#  'datavic:CROWNLAND_PLM25_WILDERNESS']

# %%
# alternatively,
import pandas as pd
contents = pd.DataFrame({'Contents': list(wfs11.contents)}) 
contents
# Out:
#                                     Contents
# 0     datavic:WATER_ISC2010_BANKFULL_WIDTH_R
# 1          datavic:WATER_ISC2010_BARE_GROUND
# 2    datavic:WATER_ISC2010_CHANNEL_TRANSECTS
# 3        datavic:WATER_ISC2010_FRAGMENTATION
# 4          datavic:WATER_ISC2010_LARGE_TREES
# ..                                       ...
# 646   datavic:FLORAFAUNA1_NV2005_EVCBCS_18_1
# 647         datavic:FLORAFAUNA1_WETLAND_1788
# 648       datavic:VMHYDRO_WATER_STRUCT_WHARF
# 649      datavic:CROWNLAND_PLMGEN_WILDERNESS
# 650       datavic:CROWNLAND_PLM25_WILDERNESS
#
# [651 rows x 1 columns]

# %% [markdown]
# # Select any available dataset in typename and then download the GML data

# %% [markdown]
# Please do a data search in our [AURIN website](https://data.aurin.org.au/) and find datasets you'd like to download through API. Please copy **AURIN Open API ID** from the website. For more information, please check our tutorial about data search (Insert a link when it's ready). For example, if we are interested in Fire Station point level datasets, using "fire station" as the keyword, you can find datasets presenting the location of Country Fire Authority (CFA) Fire Stations across Victoria. Insert **AURIN API ID**: `aurin:datasource-VIC_Govt_DELWP-VIC_Govt_DELWP_datavic_VMFEAT_CFA_FIRE_STATION` into the following command to connect to this dataset.

# %%
response = wfs11.getfeature(typename='datavic:VMFEAT_CFA_FIRE_STATION')

# %% [markdown]
# Save response to a file. We save this dataset into [gml](https://en.wikipedia.org/wiki/Geography_Markup_Language) format. The dataset is saved under the file name of "data_fire.gml". You can find "data_fire.gml" under the current directory. If you'd like to download the dataset, please right click the file and click "download" button. Please make sure to store it into a safe and secure environment.

# %%
out = open('data_fire.gml', 'wb')
out.write(response.read())
out.close()

# %% [markdown]
# # Load the data file in geopandas and plot it

# %% [markdown]
# Now we move to data visualisation after download dataset. Use command `!pip install geopandas` to install geopandas in the SWAN environment.

# %%
# !pip install geopandas
# Out:
# Requirement already satisfied: geopandas in ./.local/lib/python3.9/site-packages (0.10.2)
# Requirement already satisfied: shapely>=1.6 in /cvmfs/sft.cern.ch/lcg/views/LCG_101swan/x86_64-centos7-gcc8-opt/lib/python3.9/site-packages (from geopandas) (1.7.1)
# Requirement already satisfied: pyproj>=2.2.0 in /cvmfs/sft.cern.ch/lcg/views/LCG_101swan/x86_64-centos7-gcc8-opt/lib/python3.9/site-packages (from geopandas) (3.0.1)
# Requirement already satisfied: fiona>=1.8 in ./.local/lib/python3.9/site-packages (from geopandas) (1.8.21)
# Requirement already satisfied: pandas>=0.25.0 in /extras/cloudstor/python/pre (from geopandas) (1.4.2)
# Requirement already satisfied: click-plugins>=1.0 in ./.local/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (1.1.1)
# Requirement already satisfied: munch in ./.local/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (2.5.0)
# Requirement already satisfied: click>=4.0 in /extras/cloudstor/python/pre (from fiona>=1.8->geopandas) (8.1.2)
# Requirement already satisfied: attrs>=17 in /extras/cloudstor/python/pre (from fiona>=1.8->geopandas) (21.4.0)
# Requirement already satisfied: cligj>=0.5 in ./.local/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (0.7.2)
# Requirement already satisfied: certifi in /cvmfs/sft.cern.ch/lcg/views/LCG_101swan/x86_64-centos7-gcc8-opt/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (2021.5.30)
# Requirement already satisfied: setuptools in /extras/cloudstor/python/pre (from fiona>=1.8->geopandas) (62.1.0)
# Requirement already satisfied: six>=1.7 in /extras/cloudstor/python/pre (from fiona>=1.8->geopandas) (1.16.0)
# Requirement already satisfied: numpy>=1.18.5 in /extras/cloudstor/python/pre (from pandas>=0.25.0->geopandas) (1.22.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /extras/cloudstor/python/pre (from pandas>=0.25.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /extras/cloudstor/python/pre (from pandas>=0.25.0->geopandas) (2022.1)

# %% [markdown]
# Visualise this dataset using `world.plot()`.

# %%
import geopandas
world = geopandas.read_file('data_fire.gml')
world.plot()
# Out:
# <AxesSubplot:>
